# %% [markdown]
# # Phase 1: Agent Fundamentals
#
# **Welcome to the Microsoft Agent Framework!**
#
# This notebook will guide you through the basics of creating and running your first AI agent.
#
# **Learning Goals:**
# - Understand the core concepts of the Agent Framework.
# - Create a simple agent.
# - Configure it with a Large Language Model (LLM).
# - Run the agent and get a response.

# %% [markdown]
# ## 1. What is an Agent?
#
# In the Microsoft Agent Framework, an **Agent** is an entity that can reason, plan, and execute tasks based on instructions. It's powered by a Large Language Model (LLM) and can be extended with tools to interact with its environment.

# %% [markdown]
# ## 1a. Setup: Install Python Packages for the Notebook Kernel
#
# To ensure the notebook has access to all required libraries, we'll install them directly into the current Python environment using `pip`. This command reads the `requirements.txt` file and installs the specified packages.
#
# Using `sys.executable` ensures we are installing the packages for the exact Python interpreter the notebook kernel is using.

# %%
# !pip install -r .devcontainer/requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jupyterlab in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 3)) (4.4.10)
# Requirement already satisfied: ipykernel in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 4)) (7.1.0)
# Requirement already satisfied: notebook in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 5)) (7.4.7)
# Requirement already satisfied: agent-framework in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 11)) (2.3.4)
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 12)) (2.3.3)
# Requirement already satisfied: matplotlib in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 13)) (3.10.7)
# Requirement already satisfied: seaborn in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 14)) (0.13.2)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 15)) (2.32.5)
# Requirement already satisfied: azure-identity in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 18)) (1.25.1)
# Requirement already satisfied: azure-ai-inference in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 19)) (1.0.0b9)
# Requirement already satisfied: azure-core in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 20)) (1.36.0)
# Requirement already satisfied: black in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 23)) (25.9.0)
# Requirement already satisfied: flake8 in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 24)) (7.3.0)
# Requirement already satisfied: pytest in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 25)) (8.4.2)
# Requirement already satisfied: pytest-asyncio in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: python-dotenv in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 29)) (1.2.1)
# Requirement already satisfied: aiohttp in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 30)) (3.13.2)
# Requirement already satisfied: pydantic in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 31)) (2.12.3)
# Requirement already satisfied: jupyter-console in /home/vscode/.local/lib/python3.11/site-packages (from jupyter->-r .devcontainer/requirements.txt (line 2)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/vscode/.local/lib/python3.11/site-packages (from jupyter->-r .devcontainer/requirements.txt (line 2)) (7.16.6)
# Requirement already satisfied: jupyter in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jupyterlab in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 3)) (4.4.10)
# Requirement already satisfied: ipykernel in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 4)) (7.1.0)
# Requirement already satisfied: notebook in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 5)) (7.4.7)
# Requirement already satisfied: agent-framework in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 11)) (2.3.4)
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 12)) (2.3.3)
# Requirement already satisfied: matplotlib in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 13)) (3.10.7)
# Requirement already satisfied: seaborn in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 14)) (0.13.2)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 15)) (2.32.5)
# Requirement already satisfied: azure-identity in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 18)) (1.25.1)
# Requirement already satisfied: azure-ai-inference in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 19)) (1.0.0b9)
# Requirement already satisfied: azure-core in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 20)) (1.36.0)
# Requirement already satisfied: black in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 23)) (25.9.0)
# Requirement already satisfied: flake8 in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 24)) (7.3.0)
# Requirement already satisfied: pytest in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 25)) (8.4.2)
# Requirement already satisfied: pytest-asyncio in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: python-dotenv in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 29)) (1.2.1)
# Requirement already satisfied: aiohttp in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 30)) (3.13.2)
# Requirement already satisfied: pydantic in /home/vscode/.local/lib/python3.11/site-packages (from -r .devcontainer/requirements.txt (line 31)) (2.12.3)
# Requirement already satisfied: jupyter-console in /home/vscode/.local/lib/python3.11/site-packages (from jupyter->-r .devcontainer/requirements.txt (line 2)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/vscode/.local/lib/python3.11/site-packages (from jupyter->-r .devcontainer/requirements.txt (line 2)) (7.16.6)
# Requirement already satisfied: ipywidgets in /home/vscode/.local/lib/python3.11/site-packages (from jupyter->-r .devcontainer/requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: jupyter-core in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.2.4)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (75.6.0)
# Requirement already satisfied: tornado>=6.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (6.5.2)
# Requirement already satisfied: traitlets in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: anyio in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (4.11.0)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: comm>=0.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (9.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (7.1.2)
# Requirement already satisfied: agent-framework-core in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-a2a in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-azure-ai in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-copilotstudio in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-lab in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-redis in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-devui in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-purview in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas->-r .devcontainer/requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: ipywidgets in /home/vscode/.local/lib/python3.11/site-packages (from jupyter->-r .devcontainer/requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: jupyter-core in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.2.4)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (75.6.0)
# Requirement already satisfied: tornado>=6.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (6.5.2)
# Requirement already satisfied: traitlets in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab->-r .devcontainer/requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: anyio in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (4.11.0)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in /home/vscode/.local/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/vscode/.local/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: comm>=0.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (9.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/vscode/.local/lib/python3.11/site-packages (from ipykernel->-r .devcontainer/requirements.txt (line 4)) (7.1.2)
# Requirement already satisfied: agent-framework-core in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-a2a in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-azure-ai in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-copilotstudio in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-lab in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-redis in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-devui in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: agent-framework-purview in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0b251028)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas->-r .devcontainer/requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas->-r .devcontainer/requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas->-r .devcontainer/requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r .devcontainer/requirements.txt (line 15)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r .devcontainer/requirements.txt (line 15)) (2.5.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-inference->-r .devcontainer/requirements.txt (line 19)) (0.7.2)
# Requirement already satisfied: click>=8.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (8.3.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (4.5.0)
# Requirement already satisfied: pytokens>=0.1.10 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (0.2.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from flake8->-r .devcontainer/requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas->-r .devcontainer/requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas->-r .devcontainer/requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib->-r .devcontainer/requirements.txt (line 13)) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r .devcontainer/requirements.txt (line 15)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r .devcontainer/requirements.txt (line 15)) (2.5.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r .devcontainer/requirements.txt (line 18)) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-inference->-r .devcontainer/requirements.txt (line 19)) (0.7.2)
# Requirement already satisfied: click>=8.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (8.3.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (4.5.0)
# Requirement already satisfied: pytokens>=0.1.10 in /home/vscode/.local/lib/python3.11/site-packages (from black->-r .devcontainer/requirements.txt (line 23)) (0.2.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from flake8->-r .devcontainer/requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /home/vscode/.local/lib/python3.11/site-packages (from flake8->-r .devcontainer/requirements.txt (line 24)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from flake8->-r .devcontainer/requirements.txt (line 24)) (3.4.0)
# Requirement already satisfied: iniconfig>=1 in /home/vscode/.local/lib/python3.11/site-packages (from pytest->-r .devcontainer/requirements.txt (line 25)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from pytest->-r .devcontainer/requirements.txt (line 25)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/vscode/.local/lib/python3.11/site-packages (from pytest->-r .devcontainer/requirements.txt (line 25)) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (1.22.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /home/vscode/.local/lib/python3.11/site-packages (from flake8->-r .devcontainer/requirements.txt (line 24)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from flake8->-r .devcontainer/requirements.txt (line 24)) (3.4.0)
# Requirement already satisfied: iniconfig>=1 in /home/vscode/.local/lib/python3.11/site-packages (from pytest->-r .devcontainer/requirements.txt (line 25)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from pytest->-r .devcontainer/requirements.txt (line 25)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/vscode/.local/lib/python3.11/site-packages (from pytest->-r .devcontainer/requirements.txt (line 25)) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->-r .devcontainer/requirements.txt (line 30)) (1.22.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic->-r .devcontainer/requirements.txt (line 31)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic->-r .devcontainer/requirements.txt (line 31)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic->-r .devcontainer/requirements.txt (line 31)) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.11/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic->-r .devcontainer/requirements.txt (line 31)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic->-r .devcontainer/requirements.txt (line 31)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic->-r .devcontainer/requirements.txt (line 31)) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.11/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->-r .devcontainer/requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity->-r .devcontainer/requirements.txt (line 18)) (2.23)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->-r .devcontainer/requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity->-r .devcontainer/requirements.txt (line 18)) (2.23)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: fqdn in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: isoduration in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: fqdn in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: isoduration in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: uri-template in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (24.11.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r .devcontainer/requirements.txt (line 18)) (2.10.1)
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.11/site-packages (from nbconvert->jupyter->-r .devcontainer/requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r .devcontainer/requirements.txt (line 2)) (6.3.0)
# ...
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /home/vscode/.local/lib/python3.11/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.49.1)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.38.0)
# Requirement already satisfied: websockets>=15.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (15.0.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.38.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.38.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.3.1)
# Requirement already satisfied: fastapi>=0.104.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.120.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/vscode/.local/lib/python3.11/site-packages (from fastapi>=0.104.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.0.3)
# Requirement already satisfied: httptools>=0.6.3 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: fastapi>=0.104.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.120.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/vscode/.local/lib/python3.11/site-packages (from fastapi>=0.104.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.0.3)
# Requirement already satisfied: httptools>=0.6.3 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: mem0ai>=0.1.117 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: posthog>=3.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (6.7.11)
# Requirement already satisfied: qdrant-client>=1.9.1 in /home/vscode/.local/lib/python3.11/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /home/vscode/.local/lib/python3.11/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (2.0.44)
# Requirement already satisfied: backoff>=1.10.0 in /home/vscode/.local/lib/python3.11/site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: mem0ai>=0.1.117 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: posthog>=3.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (6.7.11)
# Requirement already satisfied: qdrant-client>=1.9.1 in /home/vscode/.local/lib/python3.11/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /home/vscode/.local/lib/python3.11/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (2.0.44)
# Requirement already satisfied: backoff>=1.10.0 in /home/vscode/.local/lib/python3.11/site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /home/vscode/.local/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /home/vscode/.local/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/vscode/.local/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/vscode/.local/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: greenlet>=1 in /home/vscode/.local/lib/python3.11/site-packages (from sqlalchemy>=2.0.31->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.2.4)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/vscode/.local/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/vscode/.local/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: greenlet>=1 in /home/vscode/.local/lib/python3.11/site-packages (from sqlalchemy>=2.0.31->mem0ai>=0.1.117->agent-framework-mem0->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.2.4)
# Requirement already satisfied: redis>=6.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: python-ulid>=3.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (9.1.2)
# Requirement already satisfied: ply in /home/vscode/.local/lib/python3.11/site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.11)
# Requirement already satisfied: redis>=6.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: python-ulid>=3.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in /home/vscode/.local/lib/python3.11/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (9.1.2)
# Requirement already satisfied: ply in /home/vscode/.local/lib/python3.11/site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework->-r .devcontainer/requirements.txt (line 8)) (3.11)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r .devcontainer/requirements.txt (line 2)) (2.8)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r .devcontainer/requirements.txt (line 2)) (2.8)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/vscode/.local/lib/python3.11/site-packages (from ipywidgets->jupyter->-r .devcontainer/requirements.txt (line 2)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/vscode/.local/lib/python3.11/site-packages (from ipywidgets->jupyter->-r .devcontainer/requirements.txt (line 2)) (3.0.15)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/vscode/.local/lib/python3.11/site-packages (from ipywidgets->jupyter->-r .devcontainer/requirements.txt (line 2)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/vscode/.local/lib/python3.11/site-packages (from ipywidgets->jupyter->-r .devcontainer/requirements.txt (line 2)) (3.0.15)
# Requirement already satisfied: arrow>=0.15.0 in /home/vscode/.local/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: arrow>=0.15.0 in /home/vscode/.local/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r .devcontainer/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r .devcontainer/requirements.txt (line 4)) (0.2.3)

# %% [markdown]
# **Action**: After running the cell above, **restart the kernel** by clicking the "Restart" button in the notebook toolbar at the top of VS Code. This will ensure the newly installed packages are loaded correctly.

# %% [markdown]
# ## 2. Setup: Get Credentials from Azure
#
# Now that we have provisioned our Azure resources, let's get the connection details from our deployment. The following command will create a `.env` file in the root of this project, containing the `AZURE_OPENAI_ENDPOINT`, `AZURE_OPENAI_API_KEY`, and `AZURE_OPENAI_DEPLOYMENT_NAME` from our provisioned resources.

# %%
# !azd env get-values > .env

print("'.env' file created successfully in the root directory!")
# Out:
# '.env' file created successfully in the root directory!

# %%
import os
from dotenv import load_dotenv
from agent_framework.agent import Agent
from agent_framework.llm.azure import AzureOpenAI
from agent_framework.llm.settings import LlmSettings

# Load environment variables from .env file
load_dotenv()

# Configure the Azure OpenAI client
llm_settings = LlmSettings(
    config={
        "api_key": os.getenv("AZURE_OPENAI_API_KEY"),
        "endpoint": os.getenv("AZURE_OPENAI_ENDPOINT"),
    },
    model="gpt-4o", # Or your preferred model
)
llm = AzureOpenAI(llm_settings)

print("LLM configured successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from agent_framework.agent import Agent
#       4 from agent_framework.llm.azure import AzureOpenAI
#       5 from agent_framework.llm.settings import LlmSettings
#
# ModuleNotFoundError: No module named 'agent_framework.agent'
